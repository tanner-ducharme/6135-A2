# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math

# %%
t1 = torch.rand(5, 6, 4, 257)
t2 = torch.rand(5, 1, 1, 257)

# %%
t1+t2
# Out:
# tensor([[[[0.2627, 1.2563, 0.3518,  ..., 1.5359, 0.8884, 1.3333],
#           [0.9609, 1.0401, 1.0736,  ..., 0.7536, 0.4071, 0.8436],
#           [0.9322, 1.4148, 0.9664,  ..., 1.2020, 0.7463, 0.9903],
#           [0.4878, 1.3236, 1.0471,  ..., 1.4191, 0.4958, 1.5446]],
#
#          [[0.8333, 1.4499, 0.8253,  ..., 1.2590, 0.5377, 1.7670],
#           [0.4523, 1.9066, 0.5510,  ..., 1.0454, 0.7026, 1.0786],
#           [0.6670, 1.4025, 0.4544,  ..., 1.0047, 0.5062, 1.7462],
#           [0.6792, 1.2088, 0.8617,  ..., 1.1176, 0.9127, 1.7315]],
#
#          [[0.4043, 0.9988, 1.0635,  ..., 0.7171, 0.9157, 1.6372],
#           [0.3184, 1.1378, 0.8447,  ..., 0.8650, 0.2379, 1.3798],
#           [0.9263, 1.4634, 0.5586,  ..., 1.0691, 0.4318, 1.6588],
#           [0.8429, 1.3039, 0.7000,  ..., 1.3951, 0.9723, 0.8625]],
#
#          [[0.4102, 1.0101, 0.6337,  ..., 0.9059, 0.9415, 1.3346],
#           [0.9721, 1.0168, 0.9029,  ..., 1.4791, 1.1809, 1.6253],
# ...

# %%
t3 = torch.rand(5, 77)
t3.unsqueeze(0).shape
# Out:
# torch.Size([1, 5, 77])

# %%
t3.unsqueeze(-1).shape
# Out:
# torch.Size([5, 77, 1])

# %%
t3.unsqueeze(1).shape
# Out:
# torch.Size([5, 1, 77])

# %%
t3.unsqueeze(1).unsqueeze(1).shape
# Out:
# torch.Size([5, 1, 1, 77])

# %%
torch.tensor((1, 2))
# Out:
# tensor([1, 2])
